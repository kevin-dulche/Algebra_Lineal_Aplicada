# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[-1, 3], [2, -2]])
print(A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
vector = np.array([[2], [1]])
print(vector)
# Out:
# [[2]
#  [1]]

# %%
# %run "../Funciones_auxiliares/graficarVectores.ipynb"

# %%
print(vector)
print(vector.flatten())
# Out:
# [[2]
#  [1]]
# [2 1]

# %%
print(A)
print(A.flatten())
# Out:
# [[-1  3]
#  [ 2 -2]]
# [-1  3  2 -2]

# %%
graficarVectores([vector.flatten()], cols = 'blue')

plt.xlim(-0.5, 3)
plt.ylim(-0.5, 2)
# Out:
# (-0.5, 2.0)

# %%
vector_transformado = A.dot(vector) # producto interno de matrices
print(vector_transformado)
# Out:
# [[1]
#  [2]]

# %%
graficarVectores([vector.flatten(), vector_transformado.flatten()], cols = ['blue', 'orange'])
plt.xlim(-0.5, 2.5)
plt.ylim(-0.5, 2.5)
# Out:
# (-0.5, 2.5)

# %%
print(np.linalg.det(A))  # Determinante de A
# Out:
# -4.0

# %%
print(np.linalg.norm(vector))  # Norma del vector
print(np.linalg.norm(vector_transformado))  # Norma del vector transformado
# Out:
# 2.23606797749979
# 2.23606797749979
