# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import imageio
import pandas as pd

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kevin\desktop\algebra_lineal_aplicada\venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\kevin\desktop\algebra_lineal_aplicada\venv\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\kevin\desktop\algebra_lineal_aplicada\venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kevin\desktop\algebra_lineal_aplicada\venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kevin\desktop\algebra_lineal_aplicada\venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import sklearn.datasets
data= sklearn.datasets.fetch_olivetti_faces()

# %%
caras = pd.DataFrame([])

for i in range(50):
    cara = data.data[i].reshape(64,64)
    caraa = pd.Series(cara.flatten(), name=i)
    caras = pd.concat([caras, caraa], axis=1)

caras = caras.T

# %%
fig, axes = plt.subplots(5,10, figsize=(15,8),
                        subplot_kw = {'xticks': [], 'yticks': [],},
                        gridspec_kw = dict(hspace = 0.01, wspace=0.01))

for i, ax in enumerate(axes.flat):
    ax.imshow(caras.iloc[i].values.reshape(64,64),cmap='gray')
